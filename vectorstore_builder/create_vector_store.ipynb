# %% [markdown]
# ## Imports

# %%
import os
from langchain_community.document_loaders import PyPDFLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
from langchain_ollama import OllamaEmbeddings
from langchain_core.documents import Document
import glob

# %% [markdown]
# ## Loading docs

# %%
pdf_path_1="legal_docs/contrat_travail_1.pdf"
pdf_path_2="legal_docs/convention-premium-portage-1.pdf"
txt_path_1="legal_docs/contrat_freelance.txt"
txt_path_2="legal_docs/conditions_generales.txt"

def load_documents():
    """Load all PDF and text documents"""
    documents = []
    
    # Load PDF document
    pdf_files = [pdf_path_1, pdf_path_2]  # Update paths
    for pdf_path in pdf_files:
        try:
            pdf_loader = PyPDFLoader(pdf_path)  # Update path
            pdf_docs = pdf_loader.load()
            documents.extend(pdf_docs)
            print(f"Loaded PDF with {len(pdf_docs)} pages")
        except Exception as e:
            print(f"Error loading PDF: {e}")
    
    # Load text documents
    text_files = [txt_path_1, txt_path_2]  # Update paths

    for text_file in text_files:
        try:
            if os.path.exists(text_file):
                text_loader = TextLoader(text_file)
                text_docs = text_loader.load()
                documents.extend(text_docs)
                print(f"Loaded text file: {text_file}")
        except Exception as e:
            print(f"Error loading {text_file}: {e}")
    
    print(f"Total documents loaded: {len(documents)}")
    return documents

# %%
documents = load_documents()
# Out:
# Loaded PDF with 4 pages
# Loaded PDF with 23 pages
# Loaded text file: legal_docs/contrat_freelance.txt
# Loaded text file: legal_docs/conditions_generales.txt
# Total documents loaded: 29

# %%
print(f"First document content preview: {type(documents[0])}")
print(documents[0].metadata)
# Out:
# First document content preview: <class 'langchain_core.documents.base.Document'>
# {'producer': 'Microsoft: Print To PDF', 'creator': 'PyPDF', 'creationdate': '2025-10-29T16:36:47+01:00', 'author': '', 'moddate': '2025-10-29T16:36:47+01:00', 'title': 'Microsoft Word - Document3', 'source': 'legal_docs/contrat_travail_1.pdf', 'total_pages': 4, 'page': 0, 'page_label': '1'}

# %% [markdown]
# ## Splitting docs (Chunking)

# %%
def split_documents(documents):
    """Split documents into chunks using recursive text splitting"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=1000,           # Optimal for most use cases
        chunk_overlap=200,         # Maintains context between chunks
        length_function=len,
        is_separator_regex=False,
        separators=["\n\n", "\n", ". ", " ", ""]  # Default separators
    )
    
    chunks = text_splitter.split_documents(documents)
    print(f"Split into {len(chunks)} chunks")
    return chunks

# %%
chunks = split_documents(documents)
# Out:
# Split into 105 chunks

# %%
print(f"First document content preview: {chunks[0].page_content}")
# Out:
# First document content preview: CONTRAT DE TRAVAIL À DURÉE INDÉTERMINÉE (CDI)
#
# Entre les soussignés :
#
# La société TECHCORP SAS, au capital de 500 000 euros, immatriculée au RCS de Paris
# sous le numéro 123 456 789, dont le siège social est situé au 15 Avenue des Champs-
# Élysées, 75008 Paris, représentée par Monsieur Jean Dupont, agissant en qualité de
# Directeur Général, ci-après dénommée « l'Employeur »,
#
# D'une part,
#
# Et :
#
# Madame Marie Martin, née le 12 mars 1990 à Lyon, de nationalité française, demeurant
# au 45 rue de la République, 69002 Lyon, ci-après dénommée « le Salarié »,
#
# D'autre part,
#
# Il a été convenu et arrêté ce qui suit :
#
# ARTICLE 1 - ENGAGEMENT
#
# L'Employeur engage le Salarié qui accepte, aux clauses et conditions ci-après
# énoncées, en qualité d'Ingénieur Data Scientist, position cadre, niveau III de la
# convention collective applicable.
#
# ARTICLE 2 - DURÉE DU CONTRAT
#
# Le présent contrat est conclu pour une durée indéterminée et prendra eƯet le 1er janvier
# 2024.

# %% [markdown]
# ## Creating the vectorstore & Storing

# %%
#function to delete existing chroma db if exists (delete completely for all memories)
def delete_existing_vectorstore(persist_directory="./legal_chroma_db_"):
    """Delete existing ChromaDB vectorstore directory"""
    if os.path.exists(persist_directory):
        files = glob.glob(os.path.join(persist_directory, '*'))
        for f in files:
            os.remove(f)
        os.rmdir(persist_directory)
        print(f"Deleted existing vectorstore at {persist_directory}")
    else:
        print(f"No existing vectorstore found at {persist_directory}")

# %%
delete_existing_vectorstore()

# %%
def create_vectorstore(chunks, persist_directory="./_legal_chroma_db_"):
    """Create and persist ChromaDB vectorstore"""
    # Initialize embeddings - using OpenAI for best results
    embeddings = OllamaEmbeddings(
        model="embeddinggemma",
    )
    
    # Create vectorstore
    vectorstore = Chroma.from_documents(
        documents=chunks,
        embedding=embeddings,
        persist_directory=persist_directory
    )
    
    # Persist to disk
    vectorstore.persist()
    print(f"Vectorstore created and persisted to {persist_directory}")
    return vectorstore

# %%
vectorstore = create_vectorstore(chunks)
# Out:
# Vectorstore created and persisted to ./_legal_chroma_db_

# %% [markdown]
# ## Loading the vectorstore to use it

# %%
def load_existing_vectorstore(persist_directory="./legal_chroma_db_"):
    """Load an existing vectorstore"""
    embeddings = OllamaEmbeddings(
        model="embeddinggemma",
    )
    vectorstore = Chroma(
        persist_directory=persist_directory,
        embedding_function=embeddings
    )
    return vectorstore

# %% [markdown]
# ## Testing the code

# %%
test_query = "c'est quoi le capital de techcorp sas"
results = vectorstore.similarity_search(test_query, k=10)

# %%
results
# Out:
# [Document(metadata={'moddate': '2025-10-29T16:36:47+01:00', 'page_label': '1', 'producer': 'Microsoft: Print To PDF', 'source': 'legal_docs/contrat_travail_1.pdf', 'total_pages': 4, 'creator': 'PyPDF', 'creationdate': '2025-10-29T16:36:47+01:00', 'page': 0, 'author': '', 'title': 'Microsoft Word - Document3'}, page_content="CONTRAT DE TRAVAIL À DURÉE INDÉTERMINÉE (CDI) \n \nEntre les soussignés : \n \nLa société TECHCORP SAS, au capital de 500 000 euros, immatriculée au RCS de Paris \nsous le numéro 123 456 789, dont le siège social est situé au 15 Avenue des Champs-\nÉlysées, 75008 Paris, représentée par Monsieur Jean Dupont, agissant en qualité de \nDirecteur Général, ci-après dénommée « l'Employeur », \n \nD'une part, \n \nEt : \n \nMadame Marie Martin, née le 12 mars 1990 à Lyon, de nationalité française, demeurant \nau 45 rue de la République, 69002 Lyon, ci-après dénommée « le Salarié », \n \nD'autre part, \n \nIl a été convenu et arrêté ce qui suit : \n \nARTICLE 1 - ENGAGEMENT \n \nL'Employeur engage le Salarié qui accepte, aux clauses et conditions ci-après \nénoncées, en qualité d'Ingénieur Data Scientist, position cadre, niveau III de la \nconvention collective applicable. \n \nARTICLE 2 - DURÉE DU CONTRAT \n \nLe présent contrat est conclu pour une durée indéterminée et prendra eƯet le 1er janvier \n2024."),
#  Document(metadata={'page_label': '21', 'creator': 'PyPDF', 'moddate': "D:20211102085237Z00'00'", 'total_pages': 23, 'creationdate': "D:20211102085237Z00'00'", 'source': 'legal_docs/convention-premium-portage-1.pdf', 'page': 20, 'producer': 'GPL Ghostscript 9.50'}, page_content='peut relever soit de la classification techniciens, agents de maîtrise ou assimilé, soit de la classifica-\ntion cadres.'),
#  Document(metadata={'source': 'legal_docs/contrat_freelance.txt'}, page_content="DURÉE DE LA MISSION\n\nLa mission débutera le 1er février 2024 et se terminera le 30 juin 2024.\n\nLa durée pourra être prolongée d'un commun accord par avenant.\n\nMODALITÉS D'EXÉCUTION\n\nLe Prestataire exercera sa mission en toute indépendance.\n\nLe travail pourra être effectué à distance ou dans les locaux du Client selon les besoins.\n\nLe Prestataire devra fournir un rapport d'avancement mensuel.\n\nRÉMUNÉRATION\n\nLa rémunération est fixée à 600 euros HT par jour travaillé.\n\nLe volume estimé est de 80 jours sur la durée de la mission, soit un montant total de 48 000 euros HT.\n\nLa facturation sera effectuée mensuellement, sur présentation d'un compte-rendu d'activité.\n\nLe paiement interviendra dans un délai de 30 jours suivant la date d'émission de la facture.\n\nPROPRIÉTÉ INTELLECTUELLE\n\nL'ensemble des développements réalisés dans le cadre de cette mission seront la propriété exclusive du Client."),
#  Document(metadata={'producer': 'GPL Ghostscript 9.50', 'page': 11, 'source': 'legal_docs/convention-premium-portage-1.pdf', 'page_label': '12', 'moddate': "D:20211102085237Z00'00'", 'creationdate': "D:20211102085237Z00'00'", 'total_pages': 23, 'creator': 'PyPDF'}, page_content='CC 2017/14 167\nL ’entreprise de portage salarial apporte toute assistance utile dans la négociation, la rédaction des \ncontrats commerciaux de portage salarial, et aux bons respects des obligations légales et/ou contrac-\ntuelles entre le salarié porté et son client, notamment par le recours éventuel à une assistance juri-\ndique.\nL ’entreprise de portage salarial s’engage à facturer la prestation telle qu’elle a été négociée entre le \nclient et le salarié porté.\nL ’entreprise de portage salarial met en place et gère, pour chaque salarié porté, un compte d’ac-\ntivité, et procède au versement de la rémunération et des charges y afférant, dans les conditions \nlégales et réglementaires.\nLe compte d’activité comporte au moins les informations prévues par l’actuel article L. 1254-25 \ndu code du travail, à savoir les versements effectués par l’entreprise cliente à l’entreprise de portage'),
#  Document(metadata={'source': 'legal_docs/contrat_freelance.txt'}, page_content="PROPRIÉTÉ INTELLECTUELLE\n\nL'ensemble des développements réalisés dans le cadre de cette mission seront la propriété exclusive du Client.\n\nLe Prestataire cède au Client tous les droits de propriété intellectuelle afférents aux livrables.\n\nCONFIDENTIALITÉ\n\nLe Prestataire s'engage à ne divulguer aucune information confidentielle relative au Client ou au projet.\n\nCette obligation de confidentialité demeurera en vigueur pendant toute la durée de la mission et pendant 5 ans après sa fin.\n\nRÉSILIATION\n\nEn cas de manquement grave de l'une des parties à ses obligations, le contrat pourra être résilié de plein droit, 15 jours après l'envoi d'une mise en demeure restée sans effet.\n\nFait à Lyon, le 15 janvier 2024, en deux exemplaires.\n\nLe Client                            Le Prestataire\n(Signature)                          (Signature)"),
#  Document(metadata={'total_pages': 23, 'page_label': '13', 'source': 'legal_docs/convention-premium-portage-1.pdf', 'moddate': "D:20211102085237Z00'00'", 'creator': 'PyPDF', 'page': 12, 'creationdate': "D:20211102085237Z00'00'", 'producer': 'GPL Ghostscript 9.50'}, page_content='– les prélèvements fiscaux ;\n– les frais professionnels éventuels liés à la réalisation de missions ou à la prospection de missions.\nLe solde disponible peut être laissé en compte dans la société pour utilisation future.'),
#  Document(metadata={'page': 2, 'total_pages': 4, 'creator': 'PyPDF', 'source': 'legal_docs/contrat_travail_1.pdf', 'author': '', 'title': 'Microsoft Word - Document3', 'producer': 'Microsoft: Print To PDF', 'page_label': '3', 'moddate': '2025-10-29T16:36:47+01:00', 'creationdate': '2025-10-29T16:36:47+01:00'}, page_content="Le nombre de jours travaillés est ﬁxé à 218 jours par an, incluant la journée de solidarité. \n \nARTICLE 7 - RÉMUNÉRATION \n \nLa rémunération brute annuelle du Salarié est ﬁxée à 55 000 euros, versée en 12 \nmensualités. \n \nCette rémunération pourra être révisée annuellement lors de l'entretien individuel. \n \nLe Salarié bénéﬁcie également d'une participation aux bénéﬁces et d'un système \nd'intéressement selon les modalités déﬁnies par l'entreprise. \n \nARTICLE 8 - CONGÉS PAYÉS \n \nLe Salarié bénéﬁcie de 25 jours ouvrés de congés payés par an, conformément aux \ndispositions légales en vigueur. \n \nARTICLE 9 - AVANTAGES SOCIAUX \n \nLe Salarié bénéﬁcie des avantages suivants : \n- Mutuelle d'entreprise (prise en charge à 60% par l'employeur) \n- Tickets restaurant d'une valeur faciale de 9 euros \n- Participation aux frais de transport à hauteur de 50% \n- Accès à la salle de sport de l'entreprise \n \nARTICLE 10 - CONFIDENTIALITÉ"),
#  Document(metadata={'page_label': '19', 'creationdate': "D:20211102085237Z00'00'", 'creator': 'PyPDF', 'producer': 'GPL Ghostscript 9.50', 'total_pages': 23, 'moddate': "D:20211102085237Z00'00'", 'source': 'legal_docs/convention-premium-portage-1.pdf', 'page': 18}, page_content='174 CC 2017/14\nArticle 30\nObligations de l’employeur\n30.1. Adaptation au poste et maintien dans l’emploi\nConformément à la loi, l’employeur assure l’adaptation des salariés à leur poste de travail et veille \nau maintien de leur capacité à occuper un emploi, au regard notamment de l’évolution des emplois, \ndes technologies et des organisations.\nDans ce cadre, l’employeur s’assure, d’une part, que le salarié porté dispose des compétences \nnécessaires pour développer son activité de recherche de clients.\nIl s’assure, d’autre part, que le salarié porté, par rapport aux compétences, qualifications et \ndomaines d’expertise connues du salarié, dispose des connaissances et des compétences requises \npour préserver son offre de services au regard de son obligation de former.\n30.2. Développement des compétences et des qualifications\nConformément à la loi, l’employeur peut proposer des actions de formations qui participent au'),
#  Document(metadata={'moddate': "D:20211102085237Z00'00'", 'creationdate': "D:20211102085237Z00'00'", 'source': 'legal_docs/convention-premium-portage-1.pdf', 'creator': 'PyPDF', 'total_pages': 23, 'page': 20, 'page_label': '21', 'producer': 'GPL Ghostscript 9.50'}, page_content='La contribution égale à 1,6 % de la masse salariale quel que soit l’effectif est répartie confor-\nmément aux dispositions législatives à concurrence de 0,55 % pour les moins de 11 salariés et à \nconcurrence de 1 % à partir de 11 salariés, l’excédent étant affecté au plan de formation.\nLa contribution est répartie de la façon suivante selon la taille de l’entreprise :\n(En pourcentage.)\nENTREPRISES \n de moins\nde 11 salariés\nENTREPRISES \n de 11 à moins\nde 50 salariés\nENTREPRISES\n de 50 à moins\nde 300 salariés\nENTREPRISES\n de 300 salariés\net plus\nContributions (en pourcen-\ntage de la masse salariale)\n1,6 1,6 1,6 1,6\nRépartition des contributions avec augmentation des contributions légales professionnalisation d’au moins 0,3 %\nPlan de formation 1,15 0,7 0,6 0,6\nProfessionnalisation 0,45 0,4 0,4 0,4\nCPF – 0,2 0.2 0,2\nCIF – 0,15 0,2 0,2\nFPSPP – 0,15 0,2 0,2\nLes entreprises verseront cette contribution à l’OPCA désigné à l’article précédent au sein duquel'),
#  Document(metadata={'producer': 'Microsoft: Print To PDF', 'page_label': '2', 'total_pages': 4, 'title': 'Microsoft Word - Document3', 'page': 1, 'creationdate': '2025-10-29T16:36:47+01:00', 'author': '', 'creator': 'PyPDF', 'source': 'legal_docs/contrat_travail_1.pdf', 'moddate': '2025-10-29T16:36:47+01:00'}, page_content="ARTICLE 3 - PÉRIODE D'ESSAI \n \nLe Salarié sera soumis à une période d'essai de 3 mois, renouvelable une fois pour une \ndurée de 3 mois. \n \nDurant cette période, chacune des parties pourra mettre ﬁn au contrat de travail à tout \nmoment, moyennant le respect d'un délai de prévenance de 15 jours calendaires. \n \nARTICLE 4 - FONCTIONS \n \nLe Salarié exercera les fonctions d'Ingénieur Data Scientist. À ce titre, il sera notamment \nchargé de : \n- Développer et déployer des modèles de Machine Learning \n- Analyser de grands volumes de données \n- Collaborer avec les équipes métiers \n- Assurer la maintenance des pipelines de données \n \nARTICLE 5 - LIEU DE TRAVAIL \n \nLe lieu de travail est ﬁxé au siège social de l'entreprise situé à Paris. Le Salarié pourra \nêtre amené à se déplacer en France ou à l'étranger pour les besoins du service. \n \nLe télétravail est autorisé à hauteur de 3 jours par semaine, après validation du \nmanager. \n \nARTICLE 6 - DURÉE DU TRAVAIL")]

# %%
print(type(vectorstore))
# Out:
# <class 'langchain_community.vectorstores.chroma.Chroma'>
